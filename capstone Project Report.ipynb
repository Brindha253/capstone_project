# %% [markdown]
# Projectname : Capstone Project(Crimes in India)
# In This Project,They have given us various crimes in India State/Districe Wise In India from the Year 2001-12
# They have Asked us to Analyze the crimes year and Split into Most Sensitive Areas,Moderate Areas,Most Peaceful Areas In India and find the Cause of the Crime,how to improve the same.
#
# Phase1:In This Phase we have collected the Data for Analysing
# In general,Like Population,Area of the State,Literacy Rate,male Literacy Rate ,Female Literacy Rate ,
# All these Data are collected from Wikipedia ,Google to make sure they are accurate and correct
# we have done Analyzation in Phase1 report detaily.
#
# Phase2:
# India is State with High Populations and  diversed culture,In this Phase we started to Analyze in details,How the crimes
# are committed in our country year wise/State wise/,we will compare the same with our Literacy rate.
#
# Analysis of Literacy Rate vs Total Crimes.
# Madhya Pradesh is having highest Crimes among all the State with Low literacy rate
# Kerala is the State having Literacy rate and have moderate crimes
# The Literacy rate is mixed relationship only,
# Maharastra is the state with High Literacy Rate,but the crimes are high
# Delhi very Less in Area ,But got Maximum crimes also,population is also high.
#
#  Analysis of the type of crime vs each state vs Literacy rate.
#  We have Analysed the different type of crime ,Madhya pradesh,Up,Delhi is having the Maximum number of cases
#  Madhyapradesh,Bihar is having maximum cases for Murder,foeticide,Abandement off Suicide etc.
#  Andhrapradesh,Maharastra state is having maximum for Rape caseslike
#  Uttar Pradesh and Delhi,Kidnapping and Abduction cases are High,foeciticide
#  I feel that Literacy rate is not a cause in few factors ,as we can see a mixed relation only
#
# Analysis of year-on-year total crime rate.
# we can See Increasing trend of crimes as the year from 2001 to 12
# can be due to population increases as well
# Other Crimes are High from the year 2006-12.
# We Can See Foeticide crime is high in the year 2010,2009,2008
# Abetment of suicide is less in all the years 2001-12
# Exposure and abandonment is high in the year 2005.
# Buying of Girls for Prostitution is Less in the crimes throughout the year 2001-12.
#  Prohibition of Child Marriage Act is less throughout the year 2001-12
#  When Compared Year wise with the Total Crime rate ,2012 is the year with the Maximum crime Rate.
#
#   Analysis of area vs overall crime
# The State UttarPradesh whose Area is 240928(in Km2) is having the highest maximum Crimes(upto 6000) in the years(2001-12)
#  The State Madhya Pradesh Whose Area is (308252in Km2) is having the second Maximum Crime (upto 5500)
# The State Maharasthra Whose Area is (307713 in Km2) is having the fourth Maximum crime(less than 4000)
#  The UT Delhi Whose Area is 1484 ,has got the Third Maximum Crimes (Greater Than 4000) from the year 2001-12.
#
# Analysis of Population vs overall Crime
# The Over all crimes is directly proportional to Population
# The State UP whose population is High(199581477) is having the Most crime upto 6000 in total(from year 2001-12)
# The State MP whose Population is (72597565) is having the Second Most Crimes. Upto 5500 in total(from the year 2001-12)
# The  State Delhi whose Population is (16753235) is having the Third Most crimes greater thn 4000
#
#
# Phase3:
# In this Phase we will be working with Sql to see the different types of crimes
# The first query is to find the Maximum number of rapes & kidnapping
# To find the Lowest number of rapes/Kidnapping in the Given file
# To find the highest number of Dacoity and lowest number of Murder for the given file.
#
# Phase4:
# In this Phase ,we done the Analyse of Moderate,sensitive and peaceful Areas to Live
# We have done the Analyzation of areas,we also discussed what is the reason for crime
# and what can be done to improve us better.
#
#
# Conclusion:
# This capstone project helps me to analyze the crime of India with various discussions,
# helps us to tell in details about the crime and State with Sensitive(which is most dangerous)
# Moderate Areas ,where crime is comparetively less than compared to sensitive areas.
# and peaceful areas,where crime is less and Good to live peacefully.
